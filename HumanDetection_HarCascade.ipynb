# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayak2709/machine-Learning/blob/master/HumanDetection_HarCascade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import time
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

person_cascade = cv2.CascadeClassifier(os.path.join('full_body.xml'))
# cap = cv2.VideoCapture("/path/to/test/video")
# while True:
#     r, frame = cap.read()
    
#     if r:
frame = cv2.imread('download (1).jpg')
       
start_time = time.time()
frame = cv2.resize(frame,(640,360)) # Downscale to improve frame rate
gray_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY) # Haar-cascade classifier needs a grayscale image
rects = person_cascade.detectMultiScale(gray_frame)
        
end_time = time.time()
print("Elapsed Time:",end_time-start_time)
  
  
if(len(rects) == 0):print("absence of human")

else:print("human present",len(rects))

  
  
for (x, y, w, h) in rects:
  cv2.rectangle(frame, (x,y), (x+w,y+h),(0,255,0),2)
  
#   k = cv2.waitKey(1)
#   if k & 0xFF == ord("q"): # Exit condition
#     break
plt.imshow(frame)
# Out:
# Elapsed Time: 0.12137508392333984
# absence of human
